# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.append("../")
from src.ferramentas import detect_file_encoding

# %%
print(detect_file_encoding("..\\data\\Customer_Flight_Activity.csv"))
print(detect_file_encoding("..\\data\\Customer loyalty History.csv"))
# Out:
# ('utf_8', 0.0)
# ('utf_8', 0.0)

# %% [markdown]
# #### Download direto no kaggle por comandos
# * kaggle datasets download -d autor/dataset -p data/

# %%
df_flight = pd.read_csv("..\data\Customer_Flight_activity.csv", encoding='utf_8', sep=',')
df_membro = pd.read_csv("..\data\Customer loyalty History.csv", encoding='utf_8', sep=',')

# %%
df_flight.head()
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed
# 0                            0
# 1                            0
# 2                            0
# ...

# %%
unique_values_column1 = df_membro['Enrollment Type'].unique()
unique_values_column2 = df_membro['Enrollment Year'].unique()

print(unique_values_column1)
print(unique_values_column2)
# Out:
# ['Standard' '2018 Promotion']
# [2016 2014 2013 2012 2015 2018 2017]

# %%
percentual_null_flight = (df_membro.isnull().sum() / len(df_membro)) * 100
percentual_null_membros = (df_membro.isnull().sum() / len(df_membro)) * 100
print("percentual faltante no dataframe flight")
print(percentual_null_flight)
print("percentual faltante no dataframe Membros")
print(percentual_null_membros)
# Out:
# percentual faltante no dataframe flight
# Loyalty Number         0.000000
# Country                0.000000
# Province               0.000000
# City                   0.000000
# Postal Code            0.000000
# Gender                 0.000000
# Education              0.000000
# Salary                25.321145
# Marital Status         0.000000
# Loyalty Card           0.000000
# CLV                    0.000000
# Enrollment Type        0.000000
# Enrollment Year        0.000000
# Enrollment Month       0.000000
# Cancellation Year     87.650117
# Cancellation Month    87.650117
# dtype: float64
# percentual faltante no dataframe Membros
# Loyalty Number         0.000000
# Country                0.000000
# Province               0.000000
# City                   0.000000
# Postal Code            0.000000
# Gender                 0.000000
# Education              0.000000
# Salary                25.321145
# Marital Status         0.000000
# Loyalty Card           0.000000
# ...

# %%
# plt.figure(figsize=(10,6))
plt.figure(figsize=(10,6))
sns.heatmap(df_membro.isnull(), cbar=False)
plt.title("Mapa de Valores Faltantes")
plt.show()

# %%
df_flight.iloc[:,6].describe()
# Out:
# count    405624.000000
# mean       1208.880059
# std        1433.155320
# min           0.000000
# 25%           0.000000
# 50%         488.000000
# 75%        2336.000000
# max        6293.000000
# Name: Distance, dtype: float64

# %% [markdown]
# #### Inicio com uma analise exploratoria nos atributos do dataset
